# %% [markdown]
# ### AIM 5001 Week 7 project 2
# Group member: Xiaolan Li
# # Part 1: Introduction
# Given in the data is a set of data points on the employees who are either currently working within the company or have resigned. The objective is to identify and improve these factors to prevent loss of good people. In this assignment, I will first launch a question "which factors prompt employees to leave?" to be researched. Then I will prepare the data, do some EDA and give conclusion to each charts. Finally I will solve the question I made.

# %% [markdown]
# # Part 2: Data Summary
# The dataset can be found in [kaggle:](https://www.kaggle.com/patelprashant/employee-attrition).
# ### Description of dataset:
# AGE Numerical Value
#
# ATTRITION Employee leaving the company (0=no, 1=yes)
#
# BUSINESS TRAVEL (1=No Travel, 2=Travel Frequently, 3=Travel Rarely)
#
# DAILY RATE Numerical Value - Salary Level
#
# DEPARTMENT (1=HR, 2=R&D, 3=Sales)
#
# DISTANCE FROM HOME Numerical Value - THE DISTANCE FROM WORK TO HOME
#
# EDUCATION Numerical Value. (1 'Below College' 2 'College' 3 'Bachelor' 4 'Master' 5 'Doctor')
#
# EDUCATION FIELD (1=HR, 2=LIFE SCIENCES, 3=MARKETING, 4=MEDICAL SCIENCES, 5=OTHERS, 6= TECHNICAL)
#
# EMPLOYEE COUNT Numerical Value
#
# EMPLOYEE NUMBER Numerical Value - EMPLOYEE ID
#
# ENVIRONMENT SATISFACTION Numerical Value - SATISFACTION WITH THE ENVIRONMENT (1 'Low' 2 'Medium' 3 'High' 4 'Very High')
#
# GENDER (1=FEMALE, 2=MALE)
#
# HOURLY RATE Numerical Value - HOURLY SALARY
#
# JOB INVOLVEMENT Numerical Value - JOB INVOLVEMENT (1 'Low' 2 'Medium' 3 'High' 4 'Very High')
#
# JOB LEVEL Numerical Value - LEVEL OF JOB
#
# JOB ROLE (1=HR REP, 2=HR, 3=LAB TECHNICIAN, 4=MANAGER, 5= MANAGING DIRECTOR, 6= RESEARCH DIRECTOR, 7= RESEARCH SCIENTIST, 8=SALES EXECUTIVE, 9= SALES REPRESENTATIVE)
#
# JOB SATISFACTION Numerical Value - SATISFACTION WITH THE JOB (1 'Low' 2 'Medium' 3 'High' 4 'Very High')
#
# MARITAL STATUS (1=DIVORCED, 2=MARRIED, 3=SINGLE)
#
# MONTHLY INCOME Numerical Value - MONTHLY SALARY
#
# MONTHLY RATE Numerical Value - MONTHLY RATE
#
# NUMCOMPANIES WORKED Numerical Value - NO. OF COMPANIES WORKED AT
#
# OVER 18 (1=YES, 2=NO)
#
# OVERTIME (1=NO, 2=YES)
#
# PERCENT SALARY HIKE Numerical Value - PERCENTAGE INCREASE IN SALARY
#
# PERFORMANCE RATING Numerical Value - PERFORMANCE RATING
#
# RELATIONS SATISFACTION Numerical Value - RELATIONS SATISFACTION
#
# STANDARD HOURS Numerical Value - STANDARD HOURS
#
# STOCK OPTIONS LEVEL Numerical Value - STOCK OPTIONS (Higher the number, the more stock option an employee has)
#
# TOTAL WORKING YEARS Numerical Value - TOTAL YEARS WORKED
#
# TRAINING TIMES LAST YEAR Numerical Value - HOURS SPENT TRAINING
#
# WORK LIFE BALANCE Numerical Value - TIME SPENT BETWEEN WORK AND OUTSIDE
#
# YEARS AT COMPANY Numerical Value - TOTAL NUMBER OF YEARS AT THE COMPANY
#
# YEARS IN CURRENT ROLE Numerical Value -YEARS IN CURRENT ROLE
#
# YEARS SINCE LAST PROMOTION Numerical Value - LAST PROMOTION
#
# YEARS WITH CURRENT MANAGER Numerical Value - YEARS SPENT WITH CURRENT MANAGER

# %% [markdown]
# # Part 3: Exploratory Data Analysis (EDA)
# For data preparation, the first thing of the task is to load the data set and check the rough view of these attributes and cleasing the data.

# %%
# import pandas library.
import pandas as pd
#read dataset from github
df = pd.read_csv('https://raw.githubusercontent.com/xiaolancara/AIM-5001/master/data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# I will replace the attrition values from yes/no to 1/0

# %%
df['Attrition'] = df['Attrition'].replace(['Yes','No'],[1,0])
#check dataset after relace values
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# we can tell there is no duplicate and missing values in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# we can tell there are multiple numeric variables and several categorical variables in the dataset which includes 1470 rows data

# %%
df.shape[1]
# Out:
# 35

# %% [markdown]
# we can tell there are 35 columns in the dataset for now.

# %%
# since the total column is 35, we should set the display to max_colums to avoid omit.
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %% [markdown]
# Based on the table, a rough view of how the data is distributed.
# - mean of Attrition is 0.16, it implied that it is not a balanced attribute since we expect it to be around 0.5. below 0.5 means it has more 0 than 1 for a binary attribute.
# - EmployeeNumber has a mean of 1024, min value of 1 and max value of 2068. It means this is just categorical number as Employee ID. We will check if duplicate values in this column. If it has no duplicate values, it means it's not a useful feature. We should drop EmployeeNumber column.
# - EmployeeCount has 0 std, min and max are both 1. It is Uniform-type distribution and with no helpful for analyze. We should drop EmployeeCount column.
# - StandardHours has 0 std, min and max are both 80. It is Uniform-type distribution and with no helpful for analyze. We should drop StandardHours column.

# %%
# Check that if the EmployeeNumber column has unique value, just like the Employee ID
df.duplicated(subset=['EmployeeNumber']).sum()
# Out:
# 0

# %% [markdown]
# we can tell 'EmployeeNumber' column is like ID number. So we should drop this column because it doesn't help the analysis

# %%
# drop EmployeeNumber column
df = df.drop('EmployeeNumber',axis=1)
# drop EmployeeCount column
df = df.drop('EmployeeCount',axis=1)
# drop StandardHours column
df = df.drop('StandardHours',axis=1)

# %%
#plot numerical data histogram
df.hist(figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000243FBBB9190>,
# ...
#       dtype=object)

# %% [markdown]
# From this basic histogram(which mixed numerical and categorical data), we can see that
# - some attributes has some diverse distribution, such as Age, lead time, Education, EnvironmentSatisfaction, MonthlyIncome, PercentSalaryHike, YearsAtCompany, etc. These may be useful attributes.
# - Uniform-type distribution may not be a useful feature, such as DailyRate, HourRate and MonthlyRate.
# - Some attributes has a quite imbalanced distribution, and it may not be helpful on feature selection, such as YearsSinceLastPromotion.

# %% [markdown]
# Then we print remaining categorical data

# %%
# import matplot library
import matplotlib.pyplot as plt
# import seaborn library
import seaborn as sns

#plot categorical data
fig, axes =plt.subplots(2,4, figsize=(15,6)) #, sharex=True
axes = axes.flatten()


object_bol = df.dtypes == 'object'
for ax, catplot in zip(axes, df.dtypes[object_bol].index):
    sns.countplot(x=catplot, data=df, ax=ax, color = 'skyblue')
plt.tight_layout()  
plt.show()

# %% [markdown]
# We can tell the Over18 column has only Y values. There is no N values for comparison, so this is not a useful feature, we should drop Over18 column.

# %%
# drop over18 column
df = df.drop('Over18',axis=1)

# %%
# check the number of columns after drop
df.shape[1]
# Out:
# 31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %% [markdown]
# # Part 4: Inference

# %% [markdown]
# Then we are going to see their relationship

# %%
# label the resign percentage in each categorical features' unique values
def with_percentage_labels(PlotName):
    bars = PlotName.patches
    half = int(len(bars)/2)
    left_bars = bars[:half]
    right_bars = bars[half:]
    for left, right in zip(left_bars, right_bars):
        height_l = left.get_height()
        height_r = right.get_height()
        ##total = height_l + height_r
        ##ax.text(left.get_x() + left.get_width()/2., height_l + 40, '{0:.0%}'.format(height_l/total), ha="center")      
        PlotName.text(right.get_x() + right.get_width()/2., height_r + 40, '{0:.0%}'.format(height_r/height_l), ha="center")

# %%
# relationship of nominal categorical data on Attrition
nominal = df.select_dtypes('object')
plt.figure(figsize=(14,14))
index = 0
for catplot in nominal:        
    index +=1
    plt.subplot(4,2,index)
    ax_normalCat = sns.countplot(x=catplot,hue='Attrition', data=df)    
    ax_cat.set_xticklabels(ax_normalCat.get_xticklabels(), rotation=20, horizontalalignment='right')
    with_percentage_labels(ax_normalCat)

plt.tight_layout()  
plt.show()

# %% [markdown]
# Conclusion: Based on this countplot, we have following findings: BusinessTravel, JobRole, MaritalStatus, OverTime features obviously has an effect on Attrition.
# - People who Travel_frequently are more likely to resign than those who don't.
# - The resign rate of MaritalStatus are Single > Married > Divorced
# - People who work overtime are more likely to resign than those who don't.
# - Different job roles affect employee attrition. People who work in the 'Sales Representative' JobRole has highest resign rate.

# %%
#get ordial features to see the relationship on Attrition
ordinal = ['Education', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'PerformanceRating',
            'RelationshipSatisfaction', 'StockOptionLevel', 'WorkLifeBalance']
# check the lenth of ordinal data can easily set the figsize of chart
len(ordinal)
# Out:
# 9

# %%
# relationship of ordinal categorical data on Attrition
plt.figure(figsize=(12,10))
index = 0
for catplot in ordinal:        
    index +=1
    plt.subplot(3,3,index)
    ax_ordinalCat = sns.countplot(x=catplot,hue='Attrition', data=df)    
    with_percentage_labels(ax_ordinalCat)
plt.tight_layout()  
plt.show()

# %% [markdown]
# Conclusion: Based on this countplot, we have following findings:
#
# - People who JobLevel is higher has lower resign rate
# - Other ordinal features don't have obvious relationship with attrition

# %% [markdown]
# Then we will run histogram to check the relationship of numerical data on Attrition

# %%
#get ordial features to see the relationship on Attrition
numerical = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
              'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole',
              'YearsSinceLastPromotion', 'YearsWithCurrManager']
# check the lenth of numerical data can easily set the figsize of chart
len(numerical)
# Out:
# 14

# %%
#relationship of numerical features---with target Attrition

# make a grid space 
fig, axes = plt.subplots(5,3, figsize=(18,15))
# hspace lets us see the names of each feature
fig.subplots_adjust(hspace=0.5)
# gives the plot a title
fig.suptitle('Numeric features against the target')
# for loop to populate each subplot with a chart
for feat, ax in zip(numerical, axes.flatten()):
    sns.histplot(data = df, x=feat, hue='Attrition', ax=ax, multiple="stack")

# %% [markdown]
# Conclusion: Based on the above histogram, we can tell Age, MonthlyIncome, PercentageSalaryHike, YearsAtCompany have obvious effects on Attrition.
# - People who has young age has higher resign rate than people in old age.
# - People who has high monthly income has lower resign rate than people has low monthly income.
# - People who has high percentage salary hike has lower resign rate than people has low percentage salary hike.
# - People who work highly Years at company has lower resign rate than people has lowly working years at company.

# %% [markdown]
# # Part 5: Conclusion

# %% [markdown]
# Based on the above charts, we can conludes that there are multiple features has obvious effect to prompt the employees to leave and related solutions are listed as below:
# - BusinessTravel: The company should give more fare to employees who travel frequently, such as increase the travel fee.
# - MaritalStatus: The company should hire more non-single employees.
# - Overtime: The company should pay attention to distribute the workload evenly among each employee to reduce overtime hours.
# - JobRoles: The company should have a meeting with Sales Representative, LaboratoryTechnician, HumanResources Job Role employees. If the problem is becauses of supervisor lack of management, the supervisor should be laid off. If not, the company should make new plans to manage these positions.
# - JobLevel: Companies should pay attention to employees in relatively low level jobs, such as increasing the amount of money available for parties and subsidies to increase their work enthusiasm.
# - Age: The company should do more training lessons for the young employees and add as much youthful energy to the company as possible. Such as build gyms, exercise equipment and space.
# - MonthlyIncome: It may not be easy for company to increase their salaries directly, but they can increase their commissions to motivate employees to work hard in exchange for higher salaries.
# - PercentageSalaryHike: The company should add a new salary increase mechanism to encourage its employees.
# - YearsAt Company: For new employees, the main reason for leaving is most likely that they are not familiar with the company environment and have no sense of belonging. Companies should increase their outdoor activities to enhance their intimacy.

# %% [markdown]
# # References

# %% [markdown]
# - https://seaborn.pydata.org/api.html
# - https://seaborn.pydata.org/generated/seaborn.histplot.html
